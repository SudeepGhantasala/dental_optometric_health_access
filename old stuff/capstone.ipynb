# %%
import pandas as pd
import requests 
import googlemaps
import folium

# %%
gmaps = googlemaps.Client(key='AIzaSyBOtOBLIf8kMlF_m-xZK_30kXh5Itk-BLc')

# %%
alphabet = gmaps.places(query='dentis', 
                            location = (36.167674353316976, -86.77570119040494), 
                            radius = 50000)

# %%
alphabet
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uECJJwJktsAJ9cP7hm9GVQ-MmV0pQK3-o9uy4CFZdr89gVGn9drxRQQ_NsJKjVZIKYVsRfacIeMdXRSqHbd_066kV0msndIuPRwN0WKfzmUCBgxQelYDrP6ITJXo35f_B3iqzkWGC6JLB-yPAglcSvP5hzRoYqFPl019XwwuMsJfAsP6x-9fFw9P_3Zpu4TXQ_DRHmWYqjI5tpMiUaSaQSovmIQpwajLrW_PwR0a66o27k77rCBbPhf_FjGYCj1MCXGkoyKtdZfiwRO7A0xsLFkrqLB_ZvSn9dO758YIXlLUauFHkdKCERTqSLQyfvEck_d6lrIwopUMj3YKtHWORNByAnJKzP5UNYOjtQAv2rg530vwI88yyx2oPBhMOu_MD2gp163wTt7IpGsRBV121DiFenDv-uKFLjjPk4K53aXcNy-JMT-tPHEDxzTTEA',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': '934 Oldham Dr Suite 100, Nolensville, TN 37135, United States',
#    'geometry': {'location': {'lat': 35.9615793, 'lng': -86.6714768},
#     'viewport': {'northeast': {'lat': 35.96299957989272,
#       'lng': -86.67014972010728},
#      'southwest': {'lat': 35.96029992010727, 'lng': -86.67284937989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
# ...

# %%
type(nash_dentist)
# Out:
# dict

# %%
df = pd.DataFrame.from_dict(nash_dentist, orient='index').transpose().drop(columns = 'html_attributions')

# %%
for index, a in df['results'].iteritems():
    try:
        print(df['results'][index]['name'])
    except:
        print('no')
# Out:
# Dentistry by Elias L Hanosh
# Dental Design Studios LLC
# Brentwood Aesthetic & Family Dentists
# South Grove Family Dentistry
# Midsouth Family Dentistry: John Craig, DDS
# Mill Creek Dental
# Paul J. Denemark, DDS
# Nolensville Dental
# Meridian Dental Centre
# Lenox Village Dentistry
# Oak Hill Family Dentistry PLLC
# Emergency Dentist 24/7 Nolensville
# Family Dental Care Of Smyrna
# Definition Dental and Wellness Spa
# Adam Cottrill, DMD
# Dentistry
# Middle Tennessee Orthodontic
# Dr. Jared D. Anway, DDS
# Music City Dental
# First Impressions Pediatric Dentistry, PLLC
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ...

# %%
df.shape
# Out:
# (450, 3)

# %%
df.iloc[0]
# Out:
# next_page_token                                                    A
# results            {'business_status': 'OPERATIONAL', 'formatted_...
# status                                                             O
# Name: 0, dtype: object

# %%
df.to_csv('check.csv')

# %%
df[0:21]
# Out:
#    next_page_token                                            results status
# 0                A  {'business_status': 'OPERATIONAL', 'formatted_...      O
# 1                a  {'business_status': 'OPERATIONAL', 'formatted_...      K
# 2                p  {'business_status': 'OPERATIONAL', 'formatted_...   None
# 3                _  {'business_status': 'OPERATIONAL', 'formatted_...   None
# 4                u  {'business_status': 'OPERATIONAL', 'formatted_...   None
# 5                E  {'business_status': 'OPERATIONAL', 'formatted_...   None
# 6                D  {'business_status': 'OPERATIONAL', 'formatted_...   None
# 7                N  {'business_status': 'OPERATIONAL', 'formatted_...   None
# 8                f  {'business_status': 'OPERATIONAL', 'formatted_...   None
# 9                C  {'business_status': 'OPERATIONAL', 'formatted_...   None
# 10               z  {'business_status': 'OPERATIONAL', 'formatted_...   None
# ...
